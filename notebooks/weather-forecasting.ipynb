# %% [markdown]
# # Forecasting next 6 months weather based upon previous 15 years of weather data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
area_code = '700129'
api_secret = 'PWVW6BHSHN68KYTA99RLNNDBF'
req_type = 'csv'
df1 = pd.read_csv('https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/' + area_code + '?unitGroup=metric&include=days&key=' + api_secret + '&contentType=csv')
df1
# Out:
#                  name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0   700129, WB, India  2022-11-03     30.2     22.5  25.6          29.4
# 1   700129, WB, India  2022-11-04     30.4     20.3  24.9          29.7
# 2   700129, WB, India  2022-11-05     30.3     20.5  24.9          29.7
# 3   700129, WB, India  2022-11-06     30.4     20.9  25.2          29.9
# 4   700129, WB, India  2022-11-07     30.4     20.9  25.1          29.7
# 5   700129, WB, India  2022-11-08     30.2     20.6  25.0          29.6
# 6   700129, WB, India  2022-11-09     29.6     21.0  24.6          29.3
# 7   700129, WB, India  2022-11-10     28.4     20.8  24.2          28.3
# 8   700129, WB, India  2022-11-11     22.5     20.3  20.9          22.5
# 9   700129, WB, India  2022-11-12     23.5     20.5  21.5          23.5
# 10  700129, WB, India  2022-11-13     27.6     20.2  23.4          29.0
# 11  700129, WB, India  2022-11-14     29.7     20.1  24.4          29.2
# ...

# %%
temp = pd.DataFrame()
temp['temperature'] = df1['temp']
temp['humidity'] = df1['humidity']
temp['ph'] = 5
temp['rainfall'] = df1['precip']
temp['soil_moisture'] = 20
np.array(temp)
# Out:
# array([[25.6, 56.1,  5. ,  0. , 20. ],
#        [24.9, 51.5,  5. ,  0. , 20. ],
#        [24.9, 53.4,  5. ,  0. , 20. ],
#        [25.2, 53.6,  5. ,  0. , 20. ],
#        [25.1, 53. ,  5. ,  0. , 20. ],
#        [25. , 54. ,  5. ,  0. , 20. ],
#        [24.6, 58.3,  5. ,  0. , 20. ],
#        [24.2, 60.6,  5. ,  0.4, 20. ],
#        [20.9, 88.4,  5. , 14.8, 20. ],
#        [21.5, 91.3,  5. ,  1.5, 20. ],
#        [23.4, 78. ,  5. ,  0.1, 20. ],
#        [24.4, 59.8,  5. ,  0. , 20. ],
#        [24.2, 49.4,  5. ,  0. , 20. ],
#        [24.5, 46.7,  5. ,  0. , 20. ],
#        [24.9, 45.4,  5. ,  0. , 20. ]])

# %%
''.join(['https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/','?unitGroup=metric&include=days&key=','PWVW6BHSHN68KYTA99RLNNDBF','&contentType=csv'])
# Out:
# 'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/?unitGroup=metric&include=days&key=PWVW6BHSHN68KYTA99RLNNDBF&contentType=csv'

# %%
df1.loc[0]
# Out:
# name                                     560029, Bengaluru, KA, India
# datetime                                                   2022-11-01
# tempmax                                                          23.9
# tempmin                                                          19.0
# temp                                                             20.8
# feelslikemax                                                     23.9
# feelslikemin                                                     19.0
# feelslike                                                        20.8
# dew                                                              18.3
# humidity                                                         85.4
# precip                                                            1.7
# precipprob                                                      100.0
# precipcover                                                     29.17
# ...

# %%
from datetime import datetime

base_url = 'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/'
area_code = '&location=' + '700129'
start_date = '2020-01-01'
end_date = datetime.today().strftime('%Y-%m-%d')
api_secret = 'AHK9WQSB9HWS8TZSJZ6JMPY3W'
req_type = 'csv'
# 'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/'+area_code+'/'+start_date+'/'+end_date+'T00:00:00&location=' +area_code+ '?key='+api_secret+'&contentType=csv')
qry = base_url

df1 = pd.read_json('https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/London,UK/2020-10-01/2020-10-31?key=WVYEMBXHC5AQZEX7HQN4BNM2K')
print(df1.to_string())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 12>()
#       9 # 'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/'+area_code+'/'+start_date+'/'+end_date+'T00:00:00&location=' +area_code+ '?key='+api_secret+'&contentType=csv')
#      10 qry = base_url
# ---> 12 df1 = pd.read_json('https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/London,UK/2020-10-01/2020-10-31?key=WVYEMBXHC5AQZEX7HQN4BNM2K')
#      13 print(df1.to_string())
#
# File C:\Program Files\Python310\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# ...

# %%
https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/London,UK/2020-10-01/2020-10-31?key=WVYEMBXHC5AQZEX7HQN4BNM2K&contentType=csv
