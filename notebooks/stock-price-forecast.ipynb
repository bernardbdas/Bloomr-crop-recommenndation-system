# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import plotly

from datetime import date
import nsepy
from nsepy import get_history

# %%
sbin = get_history(symbol='SBIN',
                   start=date(2012,1,1),
                   end=date(2022,10,24))
sbin
# Out:
#            Symbol Series  Prev Close     Open     High      Low     Last  \
# Date
# 2012-01-02   SBIN     EQ     1619.05  1629.00  1636.00  1611.40  1627.50
# 2012-01-03   SBIN     EQ     1627.65  1644.00  1710.00  1643.00  1707.05
# 2012-01-04   SBIN     EQ     1705.65  1712.00  1713.90  1675.20  1692.00
# 2012-01-05   SBIN     EQ     1696.05  1696.00  1718.55  1680.05  1690.00
# 2012-01-06   SBIN     EQ     1692.45  1675.00  1707.60  1658.05  1670.00
# ...           ...    ...         ...      ...      ...      ...      ...
# 2022-10-18   SBIN     EQ      543.65   547.10   563.50   546.75   562.40
# 2022-10-19   SBIN     EQ      562.45   563.00   563.45   551.55   553.75
# 2022-10-20   SBIN     EQ      553.40   552.00   556.80   545.30   555.50
# 2022-10-21   SBIN     EQ      555.40   557.25   565.80   557.25   561.65
# 2022-10-24   SBIN     EQ      560.85   567.00   572.50   565.90   572.15
#
#               Close     VWAP    Volume      Turnover  Trades  \
# Date
# ...

# %%
area_code = '560029'
api_secret = '6P5EKWY6YRAT64S354AVPM53H'
req_type = 'csv'
df1 = pd.read_csv('https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/' + area_code + '?unitGroup=metric&include=days&key=' + api_secret + '&contentType=csv')
df1
# Out:
#                             name    datetime  tempmax  tempmin  temp  \
# 0   560029, Bengaluru, KA, India  2022-10-24     27.9     17.0  22.3
# 1   560029, Bengaluru, KA, India  2022-10-25     26.1     16.3  20.8
# 2   560029, Bengaluru, KA, India  2022-10-26     27.0     16.7  21.5
# 3   560029, Bengaluru, KA, India  2022-10-27     27.3     16.9  21.6
# 4   560029, Bengaluru, KA, India  2022-10-28     26.9     18.2  21.9
# 5   560029, Bengaluru, KA, India  2022-10-29     27.0     19.6  21.8
# 6   560029, Bengaluru, KA, India  2022-10-30     26.2     20.0  22.5
# 7   560029, Bengaluru, KA, India  2022-10-31     27.2     18.8  22.3
# 8   560029, Bengaluru, KA, India  2022-11-01     27.7     18.6  22.3
# 9   560029, Bengaluru, KA, India  2022-11-02     25.0     19.7  21.9
# 10  560029, Bengaluru, KA, India  2022-11-03     23.4     19.5  21.1
# 11  560029, Bengaluru, KA, India  2022-11-04     25.7     18.6  21.5
# 12  560029, Bengaluru, KA, India  2022-11-05     25.6     19.0  21.7
# ...

# %%
'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/+history?&aggregateHours=24&startDateTime=2019-06-13T00:00:00&endDateTime=2019-06-20T00:00:00&unitGroup=uk&contentType=csv&dayStartTime=0:0:00&dayEndTime=0:0:00&location=Sterling,VA,US&key=YOURAPIKEY'

# %%
import urllib, csv, codecs, json

try:
    ResultBytes = urllib.request.urlopen("https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/700129?unitGroup=metric&include=days&key=6P5EKWY6YRAT64S354AVPM53H&contentType=csv")
    # Parse the results as CSV
    CSVText = csv.reader(codecs.iterdecode(ResultBytes, 'utf-8'))
    # Parse the results as JSON
    jsonData = json.loads(ResultBytes)
except urllib.error.HTTPError  as e:
    ErrorInfo= e.read().decode() 
    print('Error code: ', e.code, ErrorInfo)
    sys.exit()
except  urllib.error.URLError as e:
    ErrorInfo= e.read().decode() 
    print('Error code: ', e.code,ErrorInfo)
    sys.exit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 3>()
#       6     CSVText = csv.reader(codecs.iterdecode(ResultBytes, 'utf-8'))
#       7     # Parse the results as JSON
# ----> 8     jsonData = json.loads(ResultBytes)
#       9 except urllib.error.HTTPError  as e:
#      10     ErrorInfo= e.read().decode()
#
# File C:\Program Files\Python310\lib\json\__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
# ...
